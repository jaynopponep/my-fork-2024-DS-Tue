# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
print("number of rows:", len(df_food))
df_food.head()
# Out:
# number of rows: 125
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
print(df_food.dtypes)
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_food_new = df_food[['calories_day', 'weight', 'Gender']]
df_food_new.head(len(df_food_new))
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
nan_count = df_food_new.isna().sum()
print(nan_count)
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_food_new = df_food_new.dropna()
df_food_new.head(25)
# Out:
#     calories_day                    weight  Gender
# 1            3.0                       155       1
# 2            4.0  I'm not answering this.        1
# 3            3.0             Not sure, 240       1
# 4            2.0                       190       1
# 5            3.0                       190       1
# 6            3.0                       180       2
# 7            3.0                       137       1
# 9            3.0                       125       1
# 10           3.0                       116       1
# 11           4.0                       110       1
# 12           3.0                       264       2
# 13           3.0                       123       1
# 14           3.0                       185       2
# 16           3.0                       145       1
# 17           3.0                       170       2
# 18           3.0                       135       1
# 19           2.0                       165       2
# ...

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
df_food_new = df_food_new.apply(pd.to_numeric, errors='coerce').dropna()
df_food_new.head(25) # coerce converts the invalids into NaN, so then I can just drop them with dropna() at that conversion.
# Out:
#     calories_day  weight  Gender
# 1            3.0   155.0       1
# 4            2.0   190.0       1
# 5            3.0   190.0       1
# 6            3.0   180.0       2
# 7            3.0   137.0       1
# 9            3.0   125.0       1
# 10           3.0   116.0       1
# 11           4.0   110.0       1
# 12           3.0   264.0       2
# 13           3.0   123.0       1
# 14           3.0   185.0       2
# 16           3.0   145.0       1
# 17           3.0   170.0       2
# 18           3.0   135.0       1
# 19           2.0   165.0       2
# 20           3.0   175.0       2
# 21           3.0   195.0       2
# 22           3.0   185.0       2
# 23           3.0   185.0       2
# 24           2.0   105.0       1
# 25           3.0   125.0       1
# 26           2.0   160.0       2
# 27           4.0   175.0       2
# 28           2.0   180.0       2
# 29           2.0   167.0       2

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food_new.to_csv('data/food_cleaned', index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
df_salary = pd.read_csv('data/manager_salary_2021_responses.tsv', sep='\t', header=0)
df_salary.head(20)
# Out:
#              Timestamp How old are you?   What industry do you work in?  \
# 0   4/27/2021 11:02:10            25-34    Education (Higher Education)
# 1   4/27/2021 11:02:22            25-34               Computing or Tech
# 2   4/27/2021 11:02:38            25-34   Accounting, Banking & Finance
# 3   4/27/2021 11:02:41            25-34                      Nonprofits
# 4   4/27/2021 11:02:42            25-34   Accounting, Banking & Finance
# 5   4/27/2021 11:02:46            25-34    Education (Higher Education)
# 6   4/27/2021 11:02:51            25-34                      Publishing
# 7   4/27/2021 11:03:00            25-34   Education (Primary/Secondary)
# 8   4/27/2021 11:03:01            45-54               Computing or Tech
# 9   4/27/2021 11:03:02            35-44   Accounting, Banking & Finance
# 10  4/27/2021 11:03:03            25-34                      Nonprofits
# 11  4/27/2021 11:03:07            35-44    Education (Higher Education)
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
print(len(df_salary))
# Out:
# 28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
print(df_salary.dtypes)
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary = df_salary.rename(columns={"Timestamp": "timestamp", "How old are you?": "age", "What industry do you work in?": "industry", "Job title": "title", "If your job title needs additional context, please clarify here:": "title_context"})
df_salary = df_salary.rename(columns={"What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": "salary"})
df_salary = df_salary.rename(columns={"How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.": "additional_compensation"})
df_salary = df_salary.rename(columns={"Please indicate the currency": "currency", 'If "Other," please indicate the currency here: ': 'other_currency'})
# very funny extra space for the other_currency role
df_salary = df_salary.rename(columns={"If your income needs additional context, please provide it here:": "salary_context"})
df_salary = df_salary.rename(columns={"What country do you work in?": "country", "If you're in the U.S., what state do you work in?": "state", "What city do you work in?": "city"})
df_salary = df_salary.rename(columns={"How many years of professional work experience do you have overall?": "total_yoe", "How many years of professional work experience do you have in your field?": "field_yoe"})
df_salary = df_salary.rename(columns={"What is your highest level of education completed?": "highest_education_completed", "What is your gender?": "gender", "What is your race? (Choose all that apply.)": "race"})
df_salary.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                       title title_context  salary  \
# 0        Research and Instruction Librarian           NaN  55,000
# 1  Change & Internal Communications Manager           NaN  54,600
# 2                      Marketing Specialist           NaN  34,000
# 3                           Program Manager           NaN  62,000
# 4                        Accounting Manager           NaN  60,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary['industry'].value_counts()
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_salary_tech = df_salary[df_salary['industry'] == 'Computing or Tech']

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
df_salary_tech.head(30)
# Out:
#               timestamp    age           industry  \
# 1    4/27/2021 11:02:22  25-34  Computing or Tech
# 8    4/27/2021 11:03:01  45-54  Computing or Tech
# 43   4/27/2021 11:04:04  25-34  Computing or Tech
# 44   4/27/2021 11:04:04  25-34  Computing or Tech
# 46   4/27/2021 11:04:07  35-44  Computing or Tech
# 47   4/27/2021 11:04:09  35-44  Computing or Tech
# 53   4/27/2021 11:04:19  35-44  Computing or Tech
# 68   4/27/2021 11:04:36  25-34  Computing or Tech
# 74   4/27/2021 11:04:41  35-44  Computing or Tech
# 79   4/27/2021 11:04:49  35-44  Computing or Tech
# 89   4/27/2021 11:05:04  45-54  Computing or Tech
# 95   4/27/2021 11:05:08  45-54  Computing or Tech
# 99   4/27/2021 11:05:08  55-64  Computing or Tech
# 109  4/27/2021 11:05:21  25-34  Computing or Tech
# 114  4/27/2021 11:05:25  25-34  Computing or Tech
# 132  4/27/2021 11:05:46  35-44  Computing or Tech
# 159  4/27/2021 11:06:05  25-34  Computing or Tech
# 173  4/27/2021 11:06:13  45-54  Computing or Tech
# ...

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
df_salary_tech_usd = df_salary_tech[df_salary_tech['currency'] == 'USD']
df_salary_tech_usd.head(20)
# Out:
#               timestamp    age           industry  \
# 8    4/27/2021 11:03:01  45-54  Computing or Tech
# 43   4/27/2021 11:04:04  25-34  Computing or Tech
# 44   4/27/2021 11:04:04  25-34  Computing or Tech
# 46   4/27/2021 11:04:07  35-44  Computing or Tech
# 47   4/27/2021 11:04:09  35-44  Computing or Tech
# 53   4/27/2021 11:04:19  35-44  Computing or Tech
# 68   4/27/2021 11:04:36  25-34  Computing or Tech
# 74   4/27/2021 11:04:41  35-44  Computing or Tech
# 79   4/27/2021 11:04:49  35-44  Computing or Tech
# 95   4/27/2021 11:05:08  45-54  Computing or Tech
# 99   4/27/2021 11:05:08  55-64  Computing or Tech
# 109  4/27/2021 11:05:21  25-34  Computing or Tech
# 132  4/27/2021 11:05:46  35-44  Computing or Tech
# 159  4/27/2021 11:06:05  25-34  Computing or Tech
# 173  4/27/2021 11:06:13  45-54  Computing or Tech
# 179  4/27/2021 11:06:17  35-44  Computing or Tech
# 191  4/27/2021 11:06:27  25-34  Computing or Tech
# 197  4/27/2021 11:06:35  35-44  Computing or Tech
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_tech_usd['country'].value_counts()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Pakistan                       1
# Puerto Rico                    1
# America                        1
# Uniyed states                  1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
df_salary_tech_usd = df_salary_tech_usd.replace(["United States", "USA", "U.S.", "United States of America", "United States"], "US")

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech_usd['country'].value_counts()
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
#                   ...
# Mexico               1
# United Stateds       1
# ISA                  1
# singapore            1
# Burma                1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
# all of the countries are USA, so just replace all of them 
df_salary_tech_usd['country'] = 'US'

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
df_salary_tech_usd['country'].value_counts()
# Out:
# country
# US    3777
# Name: count, dtype: int64

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
df_salary_tech_usd['salary'] = df_salary_tech_usd['salary'].str.replace(',','').astype('int64')
df_salary_tech_usd.head(500)
# Out:
#                timestamp    age           industry  \
# 8     4/27/2021 11:03:01  45-54  Computing or Tech
# 43    4/27/2021 11:04:04  25-34  Computing or Tech
# 44    4/27/2021 11:04:04  25-34  Computing or Tech
# 46    4/27/2021 11:04:07  35-44  Computing or Tech
# 47    4/27/2021 11:04:09  35-44  Computing or Tech
# ...                  ...    ...                ...
# 5295  4/27/2021 13:04:50  35-44  Computing or Tech
# 5321  4/27/2021 13:05:58  45-54  Computing or Tech
# 5324  4/27/2021 13:06:05  25-34  Computing or Tech
# 5326  4/27/2021 13:06:09  18-24  Computing or Tech
# 5350  4/27/2021 13:06:57  45-54  Computing or Tech
#
#                                   title  \
# 8                       Systems Analyst
# 43          Principal Software Engineer
# 44                 Intelligence Analyst
# 46                     Mobile developer
# 47              Product Design Director
# ...                                 ...
# 5295  Senior software developer in test
# ...

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_tech_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).round().head(50)
# who making $0 in california though
# Out:
#                                    min      mean      max
# state
# Alabama                          29120   92510.0   350000
# Alabama, District of Columbia   156000  156000.0   156000
# Alabama, Montana                 72000   72000.0    72000
# Alaska                           67000  112500.0   158000
# Arizona                          35000  104492.0   210000
# Arizona, Utah                    95000   95000.0    95000
# Arkansas                             4   74257.0   144000
# California                           0  154857.0   875000
# California, Colorado            176000  176000.0   176000
# California, Maryland             81500   81500.0    81500
# California, Oregon              200000  200000.0   200000
# Colorado                         45000  127240.0   630000
# Connecticut                      62400  128375.0   270000
# Delaware                         63000  116600.0   169000
# District of Columbia             10000  132318.0   267500
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
# oops already did that

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
# did that

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary_tech_usd['timestamp'] = pd.to_datetime(df_salary_tech_usd['timestamp'])
df_salary_tech_usd.head(45)
# Out:
#               timestamp    age           industry  \
# 8   2021-04-27 11:03:01  45-54  Computing or Tech
# 43  2021-04-27 11:04:04  25-34  Computing or Tech
# 44  2021-04-27 11:04:04  25-34  Computing or Tech
# 46  2021-04-27 11:04:07  35-44  Computing or Tech
# 47  2021-04-27 11:04:09  35-44  Computing or Tech
# 53  2021-04-27 11:04:19  35-44  Computing or Tech
# 68  2021-04-27 11:04:36  25-34  Computing or Tech
# 74  2021-04-27 11:04:41  35-44  Computing or Tech
# 79  2021-04-27 11:04:49  35-44  Computing or Tech
# 95  2021-04-27 11:05:08  45-54  Computing or Tech
# 99  2021-04-27 11:05:08  55-64  Computing or Tech
# 109 2021-04-27 11:05:21  25-34  Computing or Tech
# 132 2021-04-27 11:05:46  35-44  Computing or Tech
# 159 2021-04-27 11:06:05  25-34  Computing or Tech
# 173 2021-04-27 11:06:13  45-54  Computing or Tech
# 179 2021-04-27 11:06:17  35-44  Computing or Tech
# 191 2021-04-27 11:06:27  25-34  Computing or Tech
# 197 2021-04-27 11:06:35  35-44  Computing or Tech
# ...

# %%
df_salary_tech_usd = df_salary_tech_usd[df_salary_tech_usd['timestamp'].dt.year.isin([2021, 2022, 2023])]
df_salary_tech_usd.tail(10) # to show that there is no more 2024, only 2021 2022 and 2023
df_salary_tech_usd_21 = df_salary_tech_usd[df_salary_tech_usd['timestamp'].dt.year.isin([2021])]
df_salary_tech_usd_22 = df_salary_tech_usd[df_salary_tech_usd['timestamp'].dt.year.isin([2022])]
df_salary_tech_usd_23 = df_salary_tech_usd[df_salary_tech_usd['timestamp'].dt.year.isin([2023])]

# %%
df_salary_tech_usd_23.groupby('state')['salary'].agg(['min', 'mean', 'max']).round().head(65)
# Out:
#                   min      mean     max
# state
# Georgia         60000   60000.0   60000
# Illinois        36000   36000.0   36000
# Maryland       116421  116421.0  116421
# Massachusetts   57000   57000.0   57000
# Missouri        45109   45109.0   45109
# New Jersey      90000   90000.0   90000
# New York        65000   65000.0   65000
# Ohio            55000   55000.0   55000
# Texas           35000  112500.0  190000
# Virginia        65000   65000.0   65000

# %%
df_salary_tech_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).round().head(65)
# Out:
#                                   min      mean     max
# state
# Alabama                         29120   97738.0  350000
# Alabama, District of Columbia  156000  156000.0  156000
# Alabama, Montana                72000   72000.0   72000
# Alaska                          67000  112500.0  158000
# Arizona                         35000  104492.0  210000
# ...                               ...       ...     ...
# Utah, Vermont                  130000  130000.0  130000
# Vermont                         65000  111781.0  200000
# Virginia                        43642  127706.0  450000
# Washington                         72  151572.0  950000
# West Virginia                  116500  120500.0  125000
#
# [65 rows x 3 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
df_salary['timestamp'] = pd.to_datetime(df_salary['timestamp'])
df_salary = df_salary[df_salary['currency'] == 'USD']
df_salary = df_salary[df_salary['country'] == 'US']
df_salary['salary'] = df_salary['salary'].str.replace(',','').astype('int64')
df_salary.groupby('state')['salary'].agg(['min', 'mean', 'max']).round().head(65)
#df_salary.head(20)
# Out:
#                     min      mean     max
# state
# Alabama           15000   78927.0  173000
# Alabama, Montana  72000   72000.0   72000
# Alabama, Oregon   50000   50000.0   50000
# Alaska            47840   80993.0  130800
# Arizona           21200   74856.0  200000
# ...                 ...       ...     ...
# Virginia          20000  112051.0  570000
# Washington        16000  118707.0  868000
# West Virginia        35   61376.0  120000
# Wisconsin         28080   79583.0  161000
# Wyoming           31408   49102.0   78000
#
# [62 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
# convert to USD format:

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
